# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from urllib.request import urlopen
import yfinance as yfb

# %%
import certifi
import json

def get_filtered_companies(sector=None,industry=None):
    url = f'https://financialmodelingprep.com/api/v3/stock-screener?sector={sector}&industry={industry}&apikey=d233d0c6d018a621828c21c00b57bbca'
    response = urlopen(url, cafile=certifi.where())
    data = response.read().decode("utf-8")
    return json.loads(data)

def get_company_data(ticker,data):
    url = f'https://financialmodelingprep.com/api/v3/{data}/{ticker}?&apikey=d233d0c6d018a621828c21c00b57bbca'
    response = urlopen(url, cafile=certifi.where())
    data = response.read().decode("utf-8")
    return json.loads(data)

# %% [markdown]
# companies_data = dict()
# tickers=tech_tickers
# for ticker in tickers:
#     balance=pd.D(get_company_data(ticker,data="balance-sheet-statement"))
#     cash_flow = get_company_data(ticker,data="cash-flow-statement")
#     income = get_company_data(ticker,data="income-statement")
#     ratios = get_company_data(ticker,data="ratios")
#     companies_data[ticker]={"balance":balance,"income":income,"cash_flow":cash_flow,"ratios":ratios}
#
# with open("exercise_companies.json","w") as f:
#     json.dump(companies_data,f)

# %% [markdown]
# companies_data = dict()
# tickers=tech_tickers
# for ticker in tickers:
#     balance=pd.DataFrame(get_company_data(ticker,data="balance-sheet-statement")).to_dict(orient="list")
#     cash_flow = pd.DataFrame(get_company_data(ticker,data="cash-flow-statement")).to_dict(orient="list")
#     income = pd.DataFrame(get_company_data(ticker,data="income-statement")).to_dict(orient="list")
#     ratios = pd.DataFrame(get_company_data(ticker,data="ratios")).to_dict(orient="list")
#     companies_data[ticker]={"balance":balance,"income":income,"cash_flow":cash_flow,"ratios":ratios}
#
# with open("companies.json","w") as f:
#     json.dump(companies_data,f)

# %%
with open("companies.json","r") as f:
    companies_data=json.load(f)    
f.close()

# %%
companies_g = dict()
for company in companies_data:
    g = np.array(companies_data[company]["ratios"]["returnOnEquity"]) * (1-np.array(companies_data[company]["ratios"]["dividendPayoutRatio"]))
    companies_data[company]["ratios"]["g"]=g

# %%
companies_data
# Out:
# {'NVDA': {'balance': {'date': ['2023-01-29',
#     '2022-01-30',
#     '2021-01-31',
#     '2020-01-26',
#     '2019-01-27'],
#    'symbol': ['NVDA', 'NVDA', 'NVDA', 'NVDA', 'NVDA'],
#    'reportedCurrency': ['USD', 'USD', 'USD', 'USD', 'USD'],
#    'cik': ['0001045810',
#     '0001045810',
#     '0001045810',
#     '0001045810',
#     '0001045810'],
#    'fillingDate': ['2023-02-24',
#     '2022-03-18',
#     '2021-02-26',
#     '2020-02-20',
#     '2019-02-21'],
#    'acceptedDate': ['2023-02-24 17:23:43',
#     '2022-03-17 20:33:34',
#     '2021-02-26 17:03:14',
#     '2020-02-20 16:38:18',
#     '2019-02-21 16:37:18'],
#    'calendarYear': ['2023', '2022', '2021', '2020', '2019'],
#    'period': ['FY', 'FY', 'FY', 'FY', 'FY'],
#    'cashAndCashEquivalents': [3389000000,
#     1990000000,
#     847000000,
#     10896000000,
#     782000000],
#    'shortTermInvestments': [9907000000,
#     19218000000,
#     10714000000,
#     1000000,
#     6640000000],
# ...
